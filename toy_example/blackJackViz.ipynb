# %%
from blackJack_neural import neural_agent
from blackJack_DS import blackJackDataset
from mountainCar_DS import MountainCarDataset
from torch.utils.data import DataLoader
import json
import torch
import os

# %%
ds = blackJackDataset("./bj_opt_data.json")

# %%
net = neural_agent("cpu")

# %%
log_dir = 'log/bj_opt/checkpoint/14.pkl'
# log_dir = 'log/bad2/checkpoint/9.pkl'

# %%
net.load_state_dict(
    torch.load(
        log_dir,
        map_location=torch.device('cpu'),
    )
)
# Out:
# <All keys matched successfully>

# %%
net.state_dict().items()
# Out:
# odict_items([('decision_boundary', tensor([18.5158, 17.5004, 17.4976, 17.5382, 17.4259, 17.5039, 17.5405, 17.5507,
#         18.5280, 18.5217, 16.4774, 12.4719, 12.5073, 11.2674, 11.1663, 11.2443,
#         16.4844, 16.4955, 16.5138, 16.4898]))])
